# %%
import pandas as pd

# %%
df = pd.read_excel("powder_foundation_cussion_tone_classifier.xlsx")
df
# Out:
#             Product Title       Brand Type   Variant Name  Color HEX  \
# 0         Matte Lip Cream      wardah  lip   Red-dicted\t    #a92431
# 1         Matte Lip Cream      wardah  lip  Fuschionately    #d04483
# 2         Matte Lip Cream      wardah  lip  See You Latte    #c5807d
# 3         Matte Lip Cream      wardah  lip        Pink Me    #d86d8c
# 4         Matte Lip Cream      wardah  lip     Speachless    #d87a71
# ...                   ...         ...  ...            ...        ...
# 1376   Color Sensational®  maybelline  lip   Plum Passion  #902472\n
# 1377  Baby Lips Dr Rescue  maybelline  lip    Coral Crave    #FF8C99
# 1378           Baby Lips®  maybelline  lip       Quenched    #fff0f0
# 1379           Baby Lips®  maybelline  lip      Cherry Me    #a12d53
# 1380           Baby Lips®  maybelline  lip     Pink Punch    #de5da4
#
#             Color RGB Season 1 Name  Season 1 Percent       S1 Closest Color  \
# ...

# %%
# Simpan DataFrame ke file CSV tanpa indeks
df.to_csv('final_product_classifier.csv', index=False)
